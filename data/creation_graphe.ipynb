# %%
import pandas as pd
from collections import defaultdict
from stop import Stop

# %% [markdown]
# ## Chargement des données

# %%
routes = pd.read_csv('../IDFM-gtfs/routes.txt')
trips = pd.read_csv('../IDFM-gtfs/trips.txt')
stop_times = pd.read_csv('../IDFM-gtfs/stop_times.txt')
stops = pd.read_csv('../IDFM-gtfs/stops.txt')
# Out:
# /var/folders/0y/kz93z2gx1fn6s9_d1wp7pq300000gn/T/ipykernel_91902/298961306.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   trips = pd.read_csv('../IDFM-gtfs/trips.txt')

# %%
routes.head()
# Out:
#       route_id          agency_id route_short_name route_long_name  \
# 0  IDFM:C01371  IDFM:Operator_100                1               1
# 1  IDFM:C01286  IDFM:Operator_100              322             322
# 2  IDFM:C01153  IDFM:Operator_100              124             124
# 3  IDFM:C00173          IDFM:1081               18              18
# 4  IDFM:C00391          IDFM:1058             4334            4334
#
#    route_desc  route_type  route_url route_color route_text_color  \
# 0         NaN           1        NaN      FFBE00           000000
# 1         NaN           3        NaN      82C8E6           000000
# 2         NaN           3        NaN      FF82B4           000000
# 3         NaN           3        NaN      DB006B           FFFFFF
# 4         NaN           3        NaN      E2001A           FFFFFF
#
#    route_sort_order
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %% [markdown]
# ## Filtrage des données

# %% [markdown]
# ### Lignes et parcours

# %%
trips = trips.merge(routes[['route_id', 'route_short_name']], on='route_id', how='left')

# %%
# Sélection des lignes et parcours de metro uniquement
metro_routes = routes[routes['route_type'] == 1]['route_id']
metro_trips = trips[trips['route_id'].isin(metro_routes)]

# %%
# On sélectionne les 16 premiers parcours de chaque ligne afin d'inclure tout les chemins possibles
selected_trips = metro_trips.groupby(['route_short_name', 'direction_id']).head(16).reset_index()

selected_trips.head()
# Out:
#    index     route_id service_id  \
# 0  49891  IDFM:C01371     IDFM:1
# 1  49892  IDFM:C01371     IDFM:1
# 2  49894  IDFM:C01371     IDFM:1
# 3  49900  IDFM:C01371     IDFM:1
# 4  49901  IDFM:C01371     IDFM:1
#
#                                              trip_id  \
# 0  IDFM:RATP:107769-C01371-COU_RATP_4864461_95549...
# 1  IDFM:RATP:107769-C01371-COU_RATP_4864461_955496_3
# 2  IDFM:RATP:107769-C01371-COU_RATP_4864461_95549...
# 3  IDFM:RATP:107769-C01371-COU_RATP_4864461_955496_5
# 4  IDFM:RATP:107769-C01371-COU_RATP_4864461_955496_7
#
#                trip_headsign trip_short_name  direction_id  block_id  \
# 0  La Défense (Grande Arche)             NaN             1       NaN
# 1  La Défense (Grande Arche)             NaN             1       NaN
# 2  La Défense (Grande Arche)             NaN             1       NaN
# 3  La Défense (Grande Arche)             NaN             1       NaN
# 4  La Défense (Grande Arche)             NaN             1       NaN
#
#    shape_id  wheelchair_accessible  bikes_allowed route_short_name
# 0       NaN                      2              0                1
# 1       NaN                      2              0                1
# 2       NaN                      2              0                1
# 3       NaN                      2              0                1
# 4       NaN                      2              0                1

# %% [markdown]
# ### Arrêts

# %%
# On filtre les stop_times pour ne garder que ceux correspondants aux parcours sélectionnés
stop_times = stop_times[stop_times['trip_id'].isin(selected_trips['trip_id'])]
stop_times = stop_times.sort_values(['trip_id', 'stop_sequence'])
stop_times.head()
# Out:
#                                                    trip_id arrival_time  \
# 1432168  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:30:00
# 1432169  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:31:00
# 1432170  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:32:00
# 1432171  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:34:00
# 1432172  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:35:00
#
#         departure_time     stop_id  stop_sequence  pickup_type  drop_off_type  \
# 1432168       07:30:00  IDFM:22175              0            0              1
# 1432169       07:31:00  IDFM:22173              1            0              0
# 1432170       07:32:00  IDFM:22160              2            0              0
# 1432171       07:34:00  IDFM:22158              3            0              0
# 1432172       07:35:00  IDFM:22155              4            0              0
#
#          local_zone_id  stop_headsign  timepoint
# 1432168            NaN            NaN          1
# 1432169            NaN            NaN          1
# 1432170            NaN            NaN          1
# 1432171            NaN            NaN          1
# 1432172            NaN            NaN          1

# %%
def to_seconds(t):
    h, m, s = map(int, t.split(":"))
    return h * 3600 + m * 60 + s

# Expression des heures en secondes
stop_times['arr_sec'] = stop_times['arrival_time'].apply(to_seconds)
stop_times['dep_sec'] = stop_times['departure_time'].apply(to_seconds)

# %%
# Sélection des arrêts correspondants aux stop_times 
stops_metro = stops[stops['stop_id'].isin(stop_times['stop_id'])]
stops_metro.count()
# Out:
# stop_id                752
# stop_code                0
# stop_name              752
# stop_desc                0
# stop_lon               752
# stop_lat               752
# zone_id                752
# stop_url                 0
# location_type          752
# parent_station         752
# stop_timezone          752
# level_id                 0
# wheelchair_boarding    752
# platform_code            0
# dtype: int64

# %%
# On récupère les stops commerciaux 
stops_commercial = stops[stops['location_type'] == 1][['stop_id', 'stop_name']]
# On crée un dictionnaire {stop_id_commercial : nom_station}
parent_dict = stops_commercial.set_index('stop_id')['stop_name'].to_dict()

# %%
# Filtrage des arrêrts physiques
physical_stops = stops_metro[stops_metro["location_type"] == 0]

physical_stops.head()
# Out:
#         stop_id  stop_code      stop_name  stop_desc  stop_lon   stop_lat  \
# 60   IDFM:22009        NaN   Campo-Formio        NaN  2.358469  48.835595
# 65   IDFM:22392        NaN         Crimée        NaN  2.376936  48.890886
# 80   IDFM:21940        NaN  Marcel Sembat        NaN  2.243468  48.833808
# 119  IDFM:22133        NaN        Simplon        NaN  2.347795  48.893815
# 153  IDFM:22057        NaN       Concorde        NaN  2.323181  48.866150
#
#      zone_id  stop_url  location_type parent_station stop_timezone  level_id  \
# 60       1.0       NaN              0     IDFM:71063  Europe/Paris       NaN
# 65       1.0       NaN              0     IDFM:72013  Europe/Paris       NaN
# 80       2.0       NaN              0     IDFM:71054  Europe/Paris       NaN
# 119      1.0       NaN              0     IDFM:71556  Europe/Paris       NaN
# 153      1.0       NaN              0     IDFM:71298  Europe/Paris       NaN
#
#      wheelchair_boarding  platform_code
# 60                     2            NaN
# 65                     2            NaN
# 80                     2            NaN
# 119                    2            NaN
# 153                    2            NaN

# %%
stop_dict = {} # {stop_id: Stop()}

for row in physical_stops.itertuples(index=False):
    name = parent_dict.get(row.parent_station, row.stop_name)  # nom de la station commerciale si dispo
    key = row.parent_station if pd.notna(row.parent_station) else row.stop_id # id de la station parent si elle existe
    if key not in stop_dict:
        stop_dict[row.stop_id] = Stop(key, name, row.stop_lat, row.stop_lon)

# %%
# On ajoute les infos des stops à stop_times
stop_times = stop_times.merge(physical_stops[['stop_id', 'stop_name', 'stop_lat', 'stop_lon']], on='stop_id', how='left')
stop_times.head()
# Out:
#                                              trip_id arrival_time  \
# 0  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:30:00
# 1  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:31:00
# 2  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:32:00
# 3  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:34:00
# 4  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:35:00
#
#   departure_time     stop_id  stop_sequence  pickup_type  drop_off_type  \
# 0       07:30:00  IDFM:22175              0            0              1
# 1       07:31:00  IDFM:22173              1            0              0
# 2       07:32:00  IDFM:22160              2            0              0
# 3       07:34:00  IDFM:22158              3            0              0
# 4       07:35:00  IDFM:22155              4            0              0
#
#    local_zone_id  stop_headsign  timepoint  arr_sec  dep_sec  \
# 0            NaN            NaN          1    27000    27000
# 1            NaN            NaN          1    27060    27060
# 2            NaN            NaN          1    27120    27120
# 3            NaN            NaN          1    27240    27240
# 4            NaN            NaN          1    27300    27300
#
#            stop_name   stop_lat  stop_lon
# 0          Corvisart  48.829860  2.350611
# 1           Glacière  48.831170  2.343497
# 2      Saint-Jacques  48.832916  2.337154
# 3  Denfert-Rochereau  48.834313  2.332872
# 4            Raspail  48.839085  2.330550

# %%
stop_times = stop_times.sort_values(['trip_id', 'stop_sequence'])
stop_times['next_stop_id'] = stop_times.groupby('trip_id')['stop_id'].shift(-1) # On ajoute une colonne avec le prochain arrêt
stop_times['next_arr_sec'] = stop_times.groupby('trip_id')['arr_sec'].shift(-1) # On ajoute l'heure d'arrivé au prochain arrêt
stop_times['duration'] = stop_times['next_arr_sec'] - stop_times['dep_sec'] # Durée entre 2 arrêts consécutifs
stop_times = stop_times.merge(trips[['trip_id', 'route_short_name']], on='trip_id', how='left')

# %%
stop_times.head()
# Out:
#                                              trip_id arrival_time  \
# 0  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:30:00
# 1  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:31:00
# 2  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:32:00
# 3  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:34:00
# 4  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:35:00
#
#   departure_time     stop_id  stop_sequence  pickup_type  drop_off_type  \
# 0       07:30:00  IDFM:22175              0            0              1
# 1       07:31:00  IDFM:22173              1            0              0
# 2       07:32:00  IDFM:22160              2            0              0
# 3       07:34:00  IDFM:22158              3            0              0
# 4       07:35:00  IDFM:22155              4            0              0
#
#    local_zone_id  stop_headsign  timepoint  arr_sec  dep_sec  \
# 0            NaN            NaN          1    27000    27000
# 1            NaN            NaN          1    27060    27060
# 2            NaN            NaN          1    27120    27120
# 3            NaN            NaN          1    27240    27240
# 4            NaN            NaN          1    27300    27300
#
#            stop_name   stop_lat  stop_lon next_stop_id  next_arr_sec  \
# 0          Corvisart  48.829860  2.350611   IDFM:22173       27060.0
# 1           Glacière  48.831170  2.343497   IDFM:22160       27120.0
# 2      Saint-Jacques  48.832916  2.337154   IDFM:22158       27240.0
# 3  Denfert-Rochereau  48.834313  2.332872   IDFM:22155       27300.0
# 4            Raspail  48.839085  2.330550   IDFM:22172       27360.0
#
#    duration route_short_name
# 0      60.0                6
# 1      60.0                6
# 2     120.0                6
# 3      60.0                6
# 4      60.0                6

# %% [markdown]
# ## Construction du graphe

# %%
edges = stop_times.dropna(subset=['next_stop_id']).copy()

# %%
# u et v sont les objets Stop correspondant aux identifiants
edges['u'] = edges['stop_id'].map(stop_dict)
edges['v'] = edges['next_stop_id'].map(stop_dict)
edges.head()
# Out:
#                                              trip_id arrival_time  \
# 0  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:30:00
# 1  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:31:00
# 2  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:32:00
# 3  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:34:00
# 4  IDFM:RATP:107494-C01376-COU_RATP_5074966_11992...     07:35:00
#
#   departure_time     stop_id  stop_sequence  pickup_type  drop_off_type  \
# 0       07:30:00  IDFM:22175              0            0              1
# 1       07:31:00  IDFM:22173              1            0              0
# 2       07:32:00  IDFM:22160              2            0              0
# 3       07:34:00  IDFM:22158              3            0              0
# 4       07:35:00  IDFM:22155              4            0              0
#
#    local_zone_id  stop_headsign  timepoint  ...  dep_sec          stop_name  \
# 0            NaN            NaN          1  ...    27000          Corvisart
# 1            NaN            NaN          1  ...    27060           Glacière
# 2            NaN            NaN          1  ...    27120      Saint-Jacques
# 3            NaN            NaN          1  ...    27240  Denfert-Rochereau
# 4            NaN            NaN          1  ...    27300            Raspail
#
#     stop_lat  stop_lon  next_stop_id next_arr_sec  duration  route_short_name  \
# 0  48.829860  2.350611    IDFM:22173      27060.0      60.0                 6
# 1  48.831170  2.343497    IDFM:22160      27120.0      60.0                 6
# 2  48.832916  2.337154    IDFM:22158      27240.0     120.0                 6
# 3  48.834313  2.332872    IDFM:22155      27300.0      60.0                 6
# 4  48.839085  2.330550    IDFM:22172      27360.0      60.0                 6
#
#                                 u                               v
# 0          Corvisart (IDFM:71013)           Glacière (IDFM:71026)
# 1           Glacière (IDFM:71026)      Saint-Jacques (IDFM:71041)
# 2      Saint-Jacques (IDFM:71041)  Denfert-Rochereau (IDFM:71056)
# 3  Denfert-Rochereau (IDFM:71056)            Raspail (IDFM:71088)
# 4            Raspail (IDFM:71088)       Edgar Quinet (IDFM:71108)
#
# [5 rows x 21 columns]

# %%
# {Stop: {Stop : durée}}
graph = defaultdict(dict)
for row in edges.itertuples(index=False):
    u, v, w, route = row.u, row.v, row.duration, row.route_short_name

    if pd.notnull(u) and pd.notnull(v):
        if v not in graph[u] or graph[u][v]["duration"] > w:
            # Le graphe est non-orienté
            graph[u][v] = {"duration": w, "routes": set([route])}
        else:
            graph[u][v]["routes"].add(route)
        
        if u not in graph[v] or graph[v][u]["duration"] > w:
            graph[v][u] = {"duration": w, "routes": set([route])}
        else:
            graph[v][u]["routes"].add(route)

# %%
graph
# Out:
# defaultdict(dict,
#             {Corvisart (IDFM:71013): {Glacière (IDFM:71026): {'duration': 60.0,
#                'routes': {'6'}},
#               Place d'Italie (IDFM:71033): {'duration': 60.0,
#                'routes': {'6'}}},
#              Glacière (IDFM:71026): {Corvisart (IDFM:71013): {'duration': 60.0,
#                'routes': {'6'}},
#               Saint-Jacques (IDFM:71041): {'duration': 60.0, 'routes': {'6'}}},
#              Saint-Jacques (IDFM:71041): {Glacière (IDFM:71026): {'duration': 60.0,
#                'routes': {'6'}},
#               Denfert-Rochereau (IDFM:71056): {'duration': 60.0,
#                'routes': {'6'}}},
#              Denfert-Rochereau (IDFM:71056): {Saint-Jacques (IDFM:71041): {'duration': 60.0,
#                'routes': {'6'}},
#               Raspail (IDFM:71088): {'duration': 60.0, 'routes': {'4', '6'}},
#               Mouton-Duvernet (IDFM:73653): {'duration': 60.0,
#                'routes': {'4'}}},
#              Raspail (IDFM:71088): {Denfert-Rochereau (IDFM:71056): {'duration': 60.0,
#                'routes': {'4', '6'}},
#               Edgar Quinet (IDFM:71108): {'duration': 60.0, 'routes': {'6'}},
#               Vavin (IDFM:71117): {'duration': 60.0, 'routes': {'4'}}},
#              Edgar Quinet (IDFM:71108): {Raspail (IDFM:71088): {'duration': 60.0,
#                'routes': {'6'}},
#               Gare Montparnasse (IDFM:71139): {'duration': 60.0,
#                'routes': {'6'}}},
#              Gare Montparnasse (IDFM:71139): {Edgar Quinet (IDFM:71108): {'duration': 60.0,
#                'routes': {'6'}},
#               Pasteur (IDFM:71125): {'duration': 60.0, 'routes': {'6'}},
#               Falguière (IDFM:73641): {'duration': 60.0, 'routes': {'12'}},
#               Notre-Dame des Champs (IDFM:71138): {'duration': 60.0,
#                'routes': {'12'}},
#               Duroc (IDFM:71159): {'duration': 60.0, 'routes': {'13'}},
#               Gaîté (IDFM:73675): {'duration': 60.0, 'routes': {'13'}},
#               Saint-Placide (IDFM:71184): {'duration': 60.0, 'routes': {'4'}},
#               Vavin (IDFM:71117): {'duration': 60.0, 'routes': {'4'}}},
#              Pasteur (IDFM:71125): {Gare Montparnasse (IDFM:71139): {'duration': 60.0,
#                'routes': {'6'}},
#               Sèvres-Lecourbe (IDFM:71144): {'duration': 60.0,
#                'routes': {'6'}},
#               Volontaires (IDFM:71113): {'duration': 60.0, 'routes': {'12'}},
#               Falguière (IDFM:73641): {'duration': 60.0, 'routes': {'12'}}},
#              Sèvres-Lecourbe (IDFM:71144): {Pasteur (IDFM:71125): {'duration': 60.0,
#                'routes': {'6'}},
#               Cambronne (IDFM:71167): {'duration': 60.0, 'routes': {'6'}}},
#              Cambronne (IDFM:71167): {Sèvres-Lecourbe (IDFM:71144): {'duration': 60.0,
#                'routes': {'6'}},
#               La Motte-Picquet - Grenelle (IDFM:71199): {'duration': 60.0,
#                'routes': {'6'}}},
#              La Motte-Picquet - Grenelle (IDFM:71199): {Cambronne (IDFM:71167): {'duration': 60.0,
#                'routes': {'6'}},
#               Dupleix (IDFM:71197): {'duration': 60.0, 'routes': {'6'}},
#               Avenue Émile Zola (IDFM:71158): {'duration': 60.0,
#                'routes': {'10'}},
#               Ségur (IDFM:71157): {'duration': 60.0, 'routes': {'10'}},
#               Commerce (IDFM:71132): {'duration': 60.0, 'routes': {'8'}},
#               École Militaire (IDFM:71224): {'duration': 60.0,
#                'routes': {'8'}}},
#              Dupleix (IDFM:71197): {La Motte-Picquet - Grenelle (IDFM:71199): {'duration': 60.0,
#                'routes': {'6'}},
#               Bir-Hakeim (IDFM:473829): {'duration': 60.0, 'routes': {'6'}}},
#              Bir-Hakeim (IDFM:473829): {Dupleix (IDFM:71197): {'duration': 60.0,
#                'routes': {'6'}},
#               Passy (IDFM:71237): {'duration': 60.0, 'routes': {'6'}}},
#              Passy (IDFM:71237): {Bir-Hakeim (IDFM:473829): {'duration': 60.0,
#                'routes': {'6'}},
#               Trocadéro (IDFM:71285): {'duration': 60.0, 'routes': {'6'}}},
#              Trocadéro (IDFM:71285): {Passy (IDFM:71237): {'duration': 60.0,
#                'routes': {'6'}},
#               Boissière (IDFM:71301): {'duration': 60.0, 'routes': {'6'}},
#               Iéna (IDFM:71294): {'duration': 60.0, 'routes': {'9'}},
#               Rue de la Pompe (IDFM:71292): {'duration': 60.0,
#                'routes': {'9'}}},
#              Boissière (IDFM:71301): {Trocadéro (IDFM:71285): {'duration': 60.0,
#                'routes': {'6'}},
#               Kléber (IDFM:73656): {'duration': 60.0, 'routes': {'6'}}},
#              Kléber (IDFM:73656): {Boissière (IDFM:71301): {'duration': 60.0,
#                'routes': {'6'}},
#               Charles de Gaulle - Etoile (IDFM:71347): {'duration': 120.0,
#                'routes': {'6'}}},
#              Charles de Gaulle - Etoile (IDFM:71347): {Kléber (IDFM:73656): {'duration': 120.0,
#                'routes': {'6'}},
#               Argentine (IDFM:71348): {'duration': 60.0, 'routes': {'1'}},
#               George V (IDFM:71328): {'duration': 60.0, 'routes': {'1'}},
#               Ternes (IDFM:71367): {'duration': 60.0, 'routes': {'2'}},
#               Victor Hugo (IDFM:71315): {'duration': 60.0, 'routes': {'2'}}},
#              Porte de la Villette (IDFM:72430): {Aubervilliers-Pantin Quatre Chemins (IDFM:72460): {'duration': 60.0,
#                'routes': {'7'}},
#               Flandre - Alphonse Karr / Corentin Cariou (IDFM:72031): {'duration': 60.0,
#                'routes': {'7'}}},
#              Aubervilliers-Pantin Quatre Chemins (IDFM:72460): {Porte de la Villette (IDFM:72430): {'duration': 60.0,
#                'routes': {'7'}},
#               Fort d'Aubervilliers (IDFM:73695): {'duration': 120.0,
#                'routes': {'7'}}},
#              Fort d'Aubervilliers (IDFM:73695): {Aubervilliers-Pantin Quatre Chemins (IDFM:72460): {'duration': 120.0,
#                'routes': {'7'}},
#               La Courneuve - 8 Mai 1945 (IDFM:73696): {'duration': 60.0,
#                'routes': {'7'}}},
#              La Courneuve - 8 Mai 1945 (IDFM:73696): {Fort d'Aubervilliers (IDFM:73695): {'duration': 60.0,
#                'routes': {'7'}}},
#              Flandre - Alphonse Karr / Corentin Cariou (IDFM:72031): {Porte de la Villette (IDFM:72430): {'duration': 60.0,
#                'routes': {'7'}},
#               Crimée (IDFM:72013): {'duration': 60.0, 'routes': {'7'}}},
#              Crimée (IDFM:72013): {Flandre - Alphonse Karr / Corentin Cariou (IDFM:72031): {'duration': 60.0,
#                'routes': {'7'}},
#               Riquet (IDFM:71977): {'duration': 60.0, 'routes': {'7'}}},
#              Riquet (IDFM:71977): {Crimée (IDFM:72013): {'duration': 60.0,
#                'routes': {'7'}},
#               Stalingrad (IDFM:71961): {'duration': 60.0, 'routes': {'7'}}},
#              Stalingrad (IDFM:71961): {Riquet (IDFM:71977): {'duration': 60.0,
#                'routes': {'7'}},
#               Louis Blanc (IDFM:71407): {'duration': 60.0, 'routes': {'7'}},
#               Gare du Nord (IDFM:71410): {'duration': 120.0, 'routes': {'5'}},
#               Jaurès (IDFM:71940): {'duration': 60.0, 'routes': {'2', '5'}},
#               La Chapelle (IDFM:71434): {'duration': 60.0, 'routes': {'2'}}},
#              Louis Blanc (IDFM:71407): {Stalingrad (IDFM:71961): {'duration': 60.0,
#                'routes': {'7'}},
#               Château Landon (IDFM:474149): {'duration': 60.0,
#                'routes': {'7'}},
#               Jaurès (IDFM:71940): {'duration': 60.0, 'routes': {'7B'}}},
#              Château Landon (IDFM:474149): {Louis Blanc (IDFM:71407): {'duration': 60.0,
#                'routes': {'7'}},
#               Gare de l'Est (IDFM:71359): {'duration': 60.0, 'routes': {'7'}}},
#              Gare de l'Est (IDFM:71359): {Château Landon (IDFM:474149): {'duration': 60.0,
#                'routes': {'7'}},
#               Poissonnière (IDFM:71363): {'duration': 60.0, 'routes': {'7'}},
#               Jacques Bonsergent (IDFM:71322): {'duration': 60.0,
#                'routes': {'5'}},
#               Gare du Nord (IDFM:71410): {'duration': 60.0, 'routes': {'4'}},
#               Château d'Eau (IDFM:71333): {'duration': 60.0, 'routes': {'4'}}},
#              Poissonnière (IDFM:71363): {Gare de l'Est (IDFM:71359): {'duration': 60.0,
#                'routes': {'7'}},
#               Cadet (IDFM:71351): {'duration': 60.0, 'routes': {'7'}}},
#              Cadet (IDFM:71351): {Poissonnière (IDFM:71363): {'duration': 60.0,
#                'routes': {'7'}},
#               Le Peletier (IDFM:478885): {'duration': 60.0, 'routes': {'7'}}},
#              Le Peletier (IDFM:478885): {Cadet (IDFM:71351): {'duration': 60.0,
#                'routes': {'7'}},
#               Chaussée d'Antin - La Fayette (IDFM:73689): {'duration': 60.0,
#                'routes': {'7'}}},
#              Chaussée d'Antin - La Fayette (IDFM:73689): {Le Peletier (IDFM:478885): {'duration': 60.0,
#                'routes': {'7'}},
#               Opéra (IDFM:71337): {'duration': 60.0, 'routes': {'7'}},
#               Richelieu - Drouot (IDFM:71330): {'duration': 60.0,
#                'routes': {'9'}},
#               Havre - Caumartin (IDFM:482368): {'duration': 60.0,
#                'routes': {'9'}}},
#              Opéra (IDFM:71337): {Chaussée d'Antin - La Fayette (IDFM:73689): {'duration': 60.0,
#                'routes': {'7'}},
#               Pyramides (IDFM:73788): {'duration': 60.0, 'routes': {'7'}},
#               Quatre Septembre (IDFM:71313): {'duration': 60.0,
#                'routes': {'3'}},
#               Havre - Caumartin (IDFM:482368): {'duration': 60.0,
#                'routes': {'3'}},
#               Madeleine (IDFM:71324): {'duration': 60.0, 'routes': {'8'}},
#               Richelieu - Drouot (IDFM:71330): {'duration': 60.0,
#                'routes': {'8'}}},
#              Pyramides (IDFM:73788): {Opéra (IDFM:71337): {'duration': 60.0,
#                'routes': {'7'}},
#               Palais Royal - Musée du Louvre (IDFM:71297): {'duration': 60.0,
#                'routes': {'7'}},
#               Châtelet (IDFM:71264): {'duration': 60.0, 'routes': {'14'}},
#               Madeleine (IDFM:71324): {'duration': 60.0, 'routes': {'14'}}},
#              Palais Royal - Musée du Louvre (IDFM:71297): {Pyramides (IDFM:73788): {'duration': 60.0,
#                'routes': {'7'}},
#               Pont Neuf (IDFM:71253): {'duration': 60.0, 'routes': {'7'}},
#               Tuileries (IDFM:71284): {'duration': 60.0, 'routes': {'1'}},
#               Louvre - Rivoli (IDFM:73630): {'duration': 60.0,
#                'routes': {'1'}}},
#              Pont Neuf (IDFM:71253): {Palais Royal - Musée du Louvre (IDFM:71297): {'duration': 60.0,
#                'routes': {'7'}},
#               Châtelet (IDFM:71264): {'duration': 60.0, 'routes': {'7'}}},
#              Châtelet (IDFM:71264): {Pont Neuf (IDFM:71253): {'duration': 60.0,
#                'routes': {'7'}},
#               Pont Marie (Cité des Arts) (IDFM:71217): {'duration': 60.0,
#                'routes': {'7'}},
#               Louvre - Rivoli (IDFM:73630): {'duration': 60.0,
#                'routes': {'1'}},
#               Hôtel de Ville (IDFM:415852): {'duration': 60.0,
#                'routes': {'1', '11'}},
#               Gare de Lyon (IDFM:73626): {'duration': 180.0, 'routes': {'14'}},
#               Pyramides (IDFM:73788): {'duration': 60.0, 'routes': {'14'}},
#               Les Halles (IDFM:73794): {'duration': 60.0, 'routes': {'4'}},
#               Cité (IDFM:71223): {'duration': 60.0, 'routes': {'4'}}},
#              Pont Marie (Cité des Arts) (IDFM:71217): {Châtelet (IDFM:71264): {'duration': 60.0,
#                'routes': {'7'}},
#               Sully - Morland (IDFM:71201): {'duration': 60.0,
#                'routes': {'7'}}},
#              Sully - Morland (IDFM:71201): {Pont Marie (Cité des Arts) (IDFM:71217): {'duration': 60.0,
#                'routes': {'7'}},
#               Jussieu (IDFM:71148): {'duration': 60.0, 'routes': {'7'}}},
#              Jussieu (IDFM:71148): {Sully - Morland (IDFM:71201): {'duration': 60.0,
#                'routes': {'7'}},
#               Place Monge (IDFM:71133): {'duration': 60.0, 'routes': {'7'}},
#               Cardinal Lemoine (IDFM:71153): {'duration': 60.0,
#                'routes': {'10'}},
#               Gare d'Austerlitz (IDFM:71135): {'duration': 120.0,
#                'routes': {'10'}}},
#              Place Monge (IDFM:71133): {Jussieu (IDFM:71148): {'duration': 60.0,
#                'routes': {'7'}},
#               Censier - Daubenton (IDFM:71100): {'duration': 60.0,
#                'routes': {'7'}}},
#              Censier - Daubenton (IDFM:71100): {Place Monge (IDFM:71133): {'duration': 60.0,
#                'routes': {'7'}},
#               Les Gobelins (IDFM:71076): {'duration': 60.0, 'routes': {'7'}}},
#              Les Gobelins (IDFM:71076): {Censier - Daubenton (IDFM:71100): {'duration': 60.0,
#                'routes': {'7'}},
#               Place d'Italie (IDFM:71033): {'duration': 60.0,
#                'routes': {'7'}}},
#              Place d'Italie (IDFM:71033): {Les Gobelins (IDFM:71076): {'duration': 60.0,
#                'routes': {'7'}},
#               Tolbiac (IDFM:71001): {'duration': 60.0, 'routes': {'7'}},
#               Campo-Formio (IDFM:71063): {'duration': 120.0, 'routes': {'5'}},
#               Nationale (IDFM:71043): {'duration': 60.0, 'routes': {'6'}},
#               Corvisart (IDFM:71013): {'duration': 60.0, 'routes': {'6'}}},
#              Tolbiac (IDFM:71001): {Place d'Italie (IDFM:71033): {'duration': 60.0,
#                'routes': {'7'}},
#               Maison Blanche (IDFM:70645): {'duration': 60.0,
#                'routes': {'7'}}},
#              Maison Blanche (IDFM:70645): {Tolbiac (IDFM:71001): {'duration': 60.0,
#                'routes': {'7'}},
#               Le Kremlin-Bicêtre (IDFM:70452): {'duration': 120.0,
#                'routes': {'7'}},
#               Porte d'Italie (IDFM:70596): {'duration': 60.0,
#                'routes': {'7'}}},
#              Le Kremlin-Bicêtre (IDFM:70452): {Maison Blanche (IDFM:70645): {'duration': 120.0,
#                'routes': {'7'}},
#               Villejuif Léo Lagrange (IDFM:70375): {'duration': 60.0,
#                'routes': {'7'}}},
#              Villejuif Léo Lagrange (IDFM:70375): {Le Kremlin-Bicêtre (IDFM:70452): {'duration': 60.0,
#                'routes': {'7'}},
#               Villejuif Paul Vaillant-Couturier (IDFM:70248): {'duration': 60.0,
#                'routes': {'7'}}},
#              Villejuif Paul Vaillant-Couturier (IDFM:70248): {Villejuif Léo Lagrange (IDFM:70375): {'duration': 60.0,
#                'routes': {'7'}},
#               Villejuif - Louis Aragon (IDFM:70143): {'duration': 180.0,
#                'routes': {'7'}}},
#              Villejuif - Louis Aragon (IDFM:70143): {Villejuif Paul Vaillant-Couturier (IDFM:70248): {'duration': 180.0,
#                'routes': {'7'}}},
#              Porte de Saint-Cloud (IDFM:71084): {Marcel Sembat (IDFM:71054): {'duration': 120.0,
#                'routes': {'9'}},
#               Exelmans (IDFM:71124): {'duration': 60.0, 'routes': {'9'}}},
#              Marcel Sembat (IDFM:71054): {Porte de Saint-Cloud (IDFM:71084): {'duration': 120.0,
#                'routes': {'9'}},
#               Billancourt (IDFM:71034): {'duration': 60.0, 'routes': {'9'}}},
#              Billancourt (IDFM:71034): {Marcel Sembat (IDFM:71054): {'duration': 60.0,
#                'routes': {'9'}},
#               Pont de Sèvres (IDFM:70698): {'duration': 60.0,
#                'routes': {'9'}}},
#              Pont de Sèvres (IDFM:70698): {Billancourt (IDFM:71034): {'duration': 60.0,
#                'routes': {'9'}}},
#              Porte de Montreuil (IDFM:71710): {Robespierre (IDFM:71725): {'duration': 120.0,
#                'routes': {'9'}},
#               Maraîchers (IDFM:71703): {'duration': 60.0, 'routes': {'9'}}},
#              Robespierre (IDFM:71725): {Porte de Montreuil (IDFM:71710): {'duration': 120.0,
#                'routes': {'9'}},
#               Croix de Chavaux (IDFM:71756): {'duration': 60.0,
#                'routes': {'9'}}},
#              Croix de Chavaux (IDFM:71756): {Robespierre (IDFM:71725): {'duration': 60.0,
#                'routes': {'9'}},
#               Mairie de Montreuil (IDFM:71785): {'duration': 60.0,
#                'routes': {'9'}}},
#              Mairie de Montreuil (IDFM:71785): {Croix de Chavaux (IDFM:71756): {'duration': 60.0,
#                'routes': {'9'}}},
#              Campo-Formio (IDFM:71063): {Place d'Italie (IDFM:71033): {'duration': 120.0,
#                'routes': {'5'}},
#               Saint-Marcel (IDFM:71092): {'duration': 60.0, 'routes': {'5'}}},
#              Saint-Marcel (IDFM:71092): {Campo-Formio (IDFM:71063): {'duration': 60.0,
#                'routes': {'5'}},
#               Gare d'Austerlitz (IDFM:71135): {'duration': 60.0,
#                'routes': {'5'}}},
#              Gare d'Austerlitz (IDFM:71135): {Saint-Marcel (IDFM:71092): {'duration': 60.0,
#                'routes': {'5'}},
#               Quai de la Rapée (IDFM:71637): {'duration': 60.0,
#                'routes': {'5'}},
#               Jussieu (IDFM:71148): {'duration': 120.0, 'routes': {'10'}}},
#              Quai de la Rapée (IDFM:71637): {Gare d'Austerlitz (IDFM:71135): {'duration': 60.0,
#                'routes': {'5'}},
#               Bastille (IDFM:463564): {'duration': 60.0, 'routes': {'5'}}},
#              Bastille (IDFM:463564): {Quai de la Rapée (IDFM:71637): {'duration': 60.0,
#                'routes': {'5'}},
#               Bréguet-Sabin (IDFM:73621): {'duration': 60.0, 'routes': {'5'}},
#               Chemin Vert (IDFM:73622): {'duration': 60.0, 'routes': {'8'}},
#               Ledru-Rollin (IDFM:71693): {'duration': 60.0, 'routes': {'8'}},
#               Saint-Paul (Le Marais) (IDFM:71222): {'duration': 120.0,
#                'routes': {'1'}},
#               Gare de Lyon (IDFM:73626): {'duration': 120.0, 'routes': {'1'}}},
#              Bréguet-Sabin (IDFM:73621): {Bastille (IDFM:463564): {'duration': 60.0,
#                'routes': {'5'}},
#               Richard-Lenoir (IDFM:73648): {'duration': 60.0,
#                'routes': {'5'}}},
#              Richard-Lenoir (IDFM:73648): {Bréguet-Sabin (IDFM:73621): {'duration': 60.0,
#                'routes': {'5'}},
#               Oberkampf (IDFM:71803): {'duration': 60.0, 'routes': {'5'}}},
#              Oberkampf (IDFM:71803): {Richard-Lenoir (IDFM:73648): {'duration': 60.0,
#                'routes': {'5'}},
#               République (IDFM:71311): {'duration': 60.0,
#                'routes': {'5', '9'}},
#               Saint-Ambroise (IDFM:71781): {'duration': 60.0,
#                'routes': {'9'}}},
#              République (IDFM:71311): {Oberkampf (IDFM:71803): {'duration': 60.0,
#                'routes': {'5', '9'}},
#               Jacques Bonsergent (IDFM:71322): {'duration': 60.0,
#                'routes': {'5'}},
#               Parmentier (IDFM:71801): {'duration': 60.0, 'routes': {'3'}},
#               Temple (IDFM:71296): {'duration': 60.0, 'routes': {'3'}},
#               Strasbourg - Saint-Denis (IDFM:73633): {'duration': 60.0,
#                'routes': {'8', '9'}},
#               Filles du Calvaire (IDFM:71277): {'duration': 60.0,
#                'routes': {'8'}},
#               Arts et Métiers (IDFM:71293): {'duration': 60.0,
#                'routes': {'11'}},
#               Goncourt (IDFM:71840): {'duration': 60.0, 'routes': {'11'}}},
#              Jacques Bonsergent (IDFM:71322): {République (IDFM:71311): {'duration': 60.0,
#                'routes': {'5'}},
#               Gare de l'Est (IDFM:71359): {'duration': 60.0, 'routes': {'5'}}},
#              Gare du Nord (IDFM:71410): {Gare de l'Est (IDFM:71359): {'duration': 60.0,
#                'routes': {'4'}},
#               Stalingrad (IDFM:71961): {'duration': 120.0, 'routes': {'5'}},
#               Barbès - Rochechouart (IDFM:71426): {'duration': 120.0,
#                'routes': {'4'}}},
#              Jaurès (IDFM:71940): {Stalingrad (IDFM:71961): {'duration': 60.0,
#                'routes': {'2', '5'}},
#               Laumière (IDFM:71957): {'duration': 60.0, 'routes': {'5'}},
#               Bolivar (IDFM:71920): {'duration': 60.0, 'routes': {'7B'}},
#               Louis Blanc (IDFM:71407): {'duration': 60.0, 'routes': {'7B'}},
#               Colonel Fabien (IDFM:71893): {'duration': 60.0,
#                'routes': {'2'}}},
#              Laumière (IDFM:71957): {Jaurès (IDFM:71940): {'duration': 60.0,
#                'routes': {'5'}},
#               Ourcq (IDFM:71972): {'duration': 60.0, 'routes': {'5'}}},
#              Ourcq (IDFM:71972): {Laumière (IDFM:71957): {'duration': 60.0,
#                'routes': {'5'}},
#               Porte de Pantin (IDFM:71989): {'duration': 60.0,
#                'routes': {'5'}}},
#              Porte de Pantin (IDFM:71989): {Ourcq (IDFM:71972): {'duration': 60.0,
#                'routes': {'5'}},
#               Hoche (IDFM:72004): {'duration': 60.0, 'routes': {'5'}}},
#              Hoche (IDFM:72004): {Porte de Pantin (IDFM:71989): {'duration': 60.0,
#                'routes': {'5'}},
#               Église de Pantin (IDFM:72024): {'duration': 60.0,
#                'routes': {'5'}}},
#              Église de Pantin (IDFM:72024): {Hoche (IDFM:72004): {'duration': 60.0,
#                'routes': {'5'}},
#               Bobigny - Pantin - Raymond Queneau (IDFM:72039): {'duration': 60.0,
#                'routes': {'5'}}},
#              Bobigny - Pantin - Raymond Queneau (IDFM:72039): {Église de Pantin (IDFM:72024): {'duration': 60.0,
#                'routes': {'5'}},
#               Bobigny Pablo Picasso (IDFM:72486): {'duration': 180.0,
#                'routes': {'5'}}},
#              Bobigny Pablo Picasso (IDFM:72486): {Bobigny - Pantin - Raymond Queneau (IDFM:72039): {'duration': 180.0,
#                'routes': {'5'}}},
#              Gambetta (IDFM:71808): {Père Lachaise (IDFM:71787): {'duration': 60.0,
#                'routes': {'3'}},
#               Porte de Bagnolet (IDFM:71799): {'duration': 60.0,
#                'routes': {'3'}},
#               Pelleport (IDFM:71828): {'duration': 60.0, 'routes': {'3B'}}},
#              Père Lachaise (IDFM:71787): {Gambetta (IDFM:71808): {'duration': 60.0,
#                'routes': {'3'}},
#               Rue Saint-Maur (IDFM:71795): {'duration': 60.0, 'routes': {'3'}},
#               Philippe Auguste (IDFM:71751): {'duration': 60.0,
#                'routes': {'2'}},
#               Ménilmontant (IDFM:71815): {'duration': 60.0, 'routes': {'2'}}},
#              Rue Saint-Maur (IDFM:71795): {Père Lachaise (IDFM:71787): {'duration': 60.0,
#                'routes': {'3'}},
#               Parmentier (IDFM:71801): {'duration': 60.0, 'routes': {'3'}}},
#              Parmentier (IDFM:71801): {Rue Saint-Maur (IDFM:71795): {'duration': 60.0,
#                'routes': {'3'}},
#               République (IDFM:71311): {'duration': 60.0, 'routes': {'3'}}},
#              Temple (IDFM:71296): {République (IDFM:71311): {'duration': 60.0,
#                'routes': {'3'}},
#               Arts et Métiers (IDFM:71293): {'duration': 60.0,
#                'routes': {'3'}}},
#              Arts et Métiers (IDFM:71293): {Temple (IDFM:71296): {'duration': 60.0,
#                'routes': {'3'}},
#               Réaumur - Sébastopol (IDFM:73636): {'duration': 60.0,
#                'routes': {'3'}},
#               Rambuteau (IDFM:71273): {'duration': 60.0, 'routes': {'11'}},
#               République (IDFM:71311): {'duration': 60.0, 'routes': {'11'}}},
#              Réaumur - Sébastopol (IDFM:73636): {Arts et Métiers (IDFM:71293): {'duration': 60.0,
#                'routes': {'3'}},
#               Sentier (IDFM:73634): {'duration': 60.0, 'routes': {'3'}},
#               Strasbourg - Saint-Denis (IDFM:73633): {'duration': 60.0,
#                'routes': {'4'}},
#               Etienne Marcel (IDFM:479068): {'duration': 60.0,
#                'routes': {'4'}}},
#              Sentier (IDFM:73634): {Réaumur - Sébastopol (IDFM:73636): {'duration': 60.0,
#                'routes': {'3'}},
#               Bourse (IDFM:73635): {'duration': 60.0, 'routes': {'3'}}},
#              Bourse (IDFM:73635): {Sentier (IDFM:73634): {'duration': 60.0,
#                'routes': {'3'}},
#               Quatre Septembre (IDFM:71313): {'duration': 60.0,
#                'routes': {'3'}}},
#              Quatre Septembre (IDFM:71313): {Bourse (IDFM:73635): {'duration': 60.0,
#                'routes': {'3'}},
#               Opéra (IDFM:71337): {'duration': 60.0, 'routes': {'3'}}},
#              Havre - Caumartin (IDFM:482368): {Opéra (IDFM:71337): {'duration': 60.0,
#                'routes': {'3'}},
#               Gare Saint-Lazare (IDFM:71370): {'duration': 60.0,
#                'routes': {'3'}},
#               Chaussée d'Antin - La Fayette (IDFM:73689): {'duration': 60.0,
#                'routes': {'9'}},
#               Saint-Augustin (IDFM:73690): {'duration': 60.0,
#                'routes': {'9'}}},
#              Gare Saint-Lazare (IDFM:71370): {Havre - Caumartin (IDFM:482368): {'duration': 60.0,
#                'routes': {'3'}},
#               Europe (IDFM:73617): {'duration': 60.0, 'routes': {'3'}},
#               Madeleine (IDFM:71324): {'duration': 60.0,
#                'routes': {'12', '14'}},
#               Trinité - d'Estienne d'Orves (IDFM:71355): {'duration': 60.0,
#                'routes': {'12'}},
#               Liège (IDFM:71382): {'duration': 60.0, 'routes': {'13'}},
#               Miromesnil (IDFM:71346): {'duration': 120.0, 'routes': {'13'}},
#               Pont Cardinet (IDFM:71475): {'duration': 120.0,
#                'routes': {'14'}}},
#              Europe (IDFM:73617): {Gare Saint-Lazare (IDFM:71370): {'duration': 60.0,
#                'routes': {'3'}},
#               Villiers (IDFM:71403): {'duration': 60.0, 'routes': {'3'}}},
#              Villiers (IDFM:71403): {Europe (IDFM:73617): {'duration': 60.0,
#                'routes': {'3'}},
#               Malesherbes (IDFM:71416): {'duration': 60.0, 'routes': {'3'}},
#               Rome (IDFM:71408): {'duration': 60.0, 'routes': {'2'}},
#               Monceau (IDFM:73671): {'duration': 60.0, 'routes': {'2'}}},
#              Malesherbes (IDFM:71416): {Villiers (IDFM:71403): {'duration': 60.0,
#                'routes': {'3'}},
#               Wagram (IDFM:71423): {'duration': 60.0, 'routes': {'3'}}},
#              Wagram (IDFM:71423): {Malesherbes (IDFM:71416): {'duration': 60.0,
#                'routes': {'3'}},
#               Péreire Levallois (IDFM:71453): {'duration': 60.0,
#                'routes': {'3'}}},
#              Péreire Levallois (IDFM:71453): {Wagram (IDFM:71423): {'duration': 60.0,
#                'routes': {'3'}},
#               Porte de Champerret (IDFM:71450): {'duration': 60.0,
#                'routes': {'3'}}},
#              Porte de Champerret (IDFM:71450): {Péreire Levallois (IDFM:71453): {'duration': 60.0,
#                'routes': {'3'}},
#               Louise Michel (IDFM:73667): {'duration': 60.0, 'routes': {'3'}}},
#              Louise Michel (IDFM:73667): {Porte de Champerret (IDFM:71450): {'duration': 60.0,
#                'routes': {'3'}},
#               Anatole France (IDFM:71519): {'duration': 60.0,
#                'routes': {'3'}}},
#              Anatole France (IDFM:71519): {Louise Michel (IDFM:73667): {'duration': 60.0,
#                'routes': {'3'}},
#               Pont de Levallois - Bécon (IDFM:72057): {'duration': 60.0,
#                'routes': {'3'}}},
#              Pont de Levallois - Bécon (IDFM:72057): {Anatole France (IDFM:71519): {'duration': 60.0,
#                'routes': {'3'}}},
#              Porte de Bagnolet (IDFM:71799): {Gambetta (IDFM:71808): {'duration': 60.0,
#                'routes': {'3'}},
#               Gallieni (IDFM:71817): {'duration': 60.0, 'routes': {'3'}}},
#              Gallieni (IDFM:71817): {Porte de Bagnolet (IDFM:71799): {'duration': 60.0,
#                'routes': {'3'}}},
#              Porte d'Auteuil (IDFM:71169): {Michel-Ange - Molitor (IDFM:73658): {'duration': 120.0,
#                'routes': {'10'}},
#               Michel-Ange - Auteuil (IDFM:71206): {'duration': 60.0,
#                'routes': {'10'}},
#               Boulogne Jean Jaurès (IDFM:71147): {'duration': 120.0,
#                'routes': {'10'}}},
#              Michel-Ange - Molitor (IDFM:73658): {Porte d'Auteuil (IDFM:71169): {'duration': 120.0,
#                'routes': {'10'}},
#               Chardon Lagache (IDFM:71141): {'duration': 60.0,
#                'routes': {'10'}},
#               Boulogne Jean Jaurès (IDFM:71147): {'duration': 120.0,
#                'routes': {'10'}},
#               Michel-Ange - Auteuil (IDFM:71206): {'duration': 60.0,
#                'routes': {'9'}},
#               Exelmans (IDFM:71124): {'duration': 60.0, 'routes': {'9'}}},
#              Chardon Lagache (IDFM:71141): {Michel-Ange - Molitor (IDFM:73658): {'duration': 60.0,
#                'routes': {'10'}},
#               Mirabeau (IDFM:71162): {'duration': 60.0, 'routes': {'10'}}},
#              Mirabeau (IDFM:71162): {Chardon Lagache (IDFM:71141): {'duration': 60.0,
#                'routes': {'10'}},
#               Javel (IDFM:71150): {'duration': 60.0, 'routes': {'10'}}},
#              Javel (IDFM:71150): {Mirabeau (IDFM:71162): {'duration': 60.0,
#                'routes': {'10'}},
#               Charles Michels (IDFM:71156): {'duration': 60.0,
#                'routes': {'10'}},
#               Église d'Auteuil (IDFM:71166): {'duration': 60.0,
#                'routes': {'10'}}},
#              Charles Michels (IDFM:71156): {Javel (IDFM:71150): {'duration': 60.0,
#                'routes': {'10'}},
#               Avenue Émile Zola (IDFM:71158): {'duration': 60.0,
#                'routes': {'10'}}},
#              Avenue Émile Zola (IDFM:71158): {Charles Michels (IDFM:71156): {'duration': 60.0,
#                'routes': {'10'}},
#               La Motte-Picquet - Grenelle (IDFM:71199): {'duration': 60.0,
#                'routes': {'10'}}},
#              Ségur (IDFM:71157): {La Motte-Picquet - Grenelle (IDFM:71199): {'duration': 60.0,
#                'routes': {'10'}},
#               Duroc (IDFM:71159): {'duration': 60.0, 'routes': {'10'}}},
#              Duroc (IDFM:71159): {Ségur (IDFM:71157): {'duration': 60.0,
#                'routes': {'10'}},
#               Vaneau (IDFM:71170): {'duration': 60.0, 'routes': {'10'}},
#               Saint-François-Xavier (IDFM:71204): {'duration': 60.0,
#                'routes': {'13'}},
#               Gare Montparnasse (IDFM:71139): {'duration': 60.0,
#                'routes': {'13'}}},
#              Vaneau (IDFM:71170): {Duroc (IDFM:71159): {'duration': 60.0,
#                'routes': {'10'}},
#               Sèvres - Babylone (IDFM:71203): {'duration': 60.0,
#                'routes': {'10'}}},
#              Sèvres - Babylone (IDFM:71203): {Vaneau (IDFM:71170): {'duration': 60.0,
#                'routes': {'10'}},
#               Mabillon (IDFM:73639): {'duration': 60.0, 'routes': {'10'}},
#               Rennes (IDFM:73640): {'duration': 60.0, 'routes': {'12'}},
#               Rue du Bac (IDFM:71227): {'duration': 60.0, 'routes': {'12'}}},
#              Mabillon (IDFM:73639): {Sèvres - Babylone (IDFM:71203): {'duration': 60.0,
#                'routes': {'10'}},
#               Odéon (IDFM:73618): {'duration': 60.0, 'routes': {'10'}}},
#              Odéon (IDFM:73618): {Mabillon (IDFM:73639): {'duration': 60.0,
#                'routes': {'10'}},
#               Cluny - La Sorbonne (IDFM:73619): {'duration': 60.0,
#                'routes': {'10'}},
#               Saint-Michel Notre-Dame (IDFM:73620): {'duration': 60.0,
#                'routes': {'4'}},
#               Saint-Germain-des-Prés (IDFM:71216): {'duration': 60.0,
#                'routes': {'4'}}},
#              Cluny - La Sorbonne (IDFM:73619): {Odéon (IDFM:73618): {'duration': 60.0,
#                'routes': {'10'}},
#               Maubert - Mutualité (IDFM:71190): {'duration': 60.0,
#                'routes': {'10'}}},
#              Maubert - Mutualité (IDFM:71190): {Cluny - La Sorbonne (IDFM:73619): {'duration': 60.0,
#                'routes': {'10'}},
#               Cardinal Lemoine (IDFM:71153): {'duration': 60.0,
#                'routes': {'10'}}},
#              Cardinal Lemoine (IDFM:71153): {Maubert - Mutualité (IDFM:71190): {'duration': 60.0,
#                'routes': {'10'}},
#               Jussieu (IDFM:71148): {'duration': 60.0, 'routes': {'10'}}},
#              Église d'Auteuil (IDFM:71166): {Javel (IDFM:71150): {'duration': 60.0,
#                'routes': {'10'}},
#               Michel-Ange - Auteuil (IDFM:71206): {'duration': 60.0,
#                'routes': {'10'}}},
#              Michel-Ange - Auteuil (IDFM:71206): {Église d'Auteuil (IDFM:71166): {'duration': 60.0,
#                'routes': {'10'}},
#               Porte d'Auteuil (IDFM:71169): {'duration': 60.0,
#                'routes': {'10'}},
#               Jasmin (IDFM:73657): {'duration': 60.0, 'routes': {'9'}},
#               Michel-Ange - Molitor (IDFM:73658): {'duration': 60.0,
#                'routes': {'9'}}},
#              Boulogne Jean Jaurès (IDFM:71147): {Porte d'Auteuil (IDFM:71169): {'duration': 120.0,
#                'routes': {'10'}},
#               Boulogne Pont de Saint-Cloud (IDFM:70721): {'duration': 120.0,
#                'routes': {'10'}},
#               Michel-Ange - Molitor (IDFM:73658): {'duration': 120.0,
#                'routes': {'10'}}},
#              Boulogne Pont de Saint-Cloud (IDFM:70721): {Boulogne Jean Jaurès (IDFM:71147): {'duration': 120.0,
#                'routes': {'10'}}},
#              Porte des Lilas (IDFM:71889): {Saint-Fargeau (IDFM:71860): {'duration': 60.0,
#                'routes': {'3B'}},
#               Télégraphe (IDFM:71870): {'duration': 60.0, 'routes': {'11'}},
#               Mairie des Lilas (IDFM:71909): {'duration': 60.0,
#                'routes': {'11'}}},
#              Saint-Fargeau (IDFM:71860): {Porte des Lilas (IDFM:71889): {'duration': 60.0,
#                'routes': {'3B'}},
#               Pelleport (IDFM:71828): {'duration': 60.0, 'routes': {'3B'}}},
#              Pelleport (IDFM:71828): {Saint-Fargeau (IDFM:71860): {'duration': 60.0,
#                'routes': {'3B'}},
#               Gambetta (IDFM:71808): {'duration': 60.0, 'routes': {'3B'}}},
#              Pré-Saint-Gervais (IDFM:71911): {Danube (IDFM:71930): {'duration': 60.0,
#                'routes': {'7B'}},
#               Place des Fêtes (IDFM:71885): {'duration': 120.0,
#                'routes': {'7B'}}},
#              Danube (IDFM:71930): {Pré-Saint-Gervais (IDFM:71911): {'duration': 60.0,
#                'routes': {'7B'}},
#               Botzaris (IDFM:71906): {'duration': 60.0, 'routes': {'7B'}}},
#              Botzaris (IDFM:71906): {Danube (IDFM:71930): {'duration': 60.0,
#                'routes': {'7B'}},
#               Buttes Chaumont (IDFM:71900): {'duration': 60.0,
#                'routes': {'7B'}},
#               Place des Fêtes (IDFM:71885): {'duration': 60.0,
#                'routes': {'7B'}}},
#              Buttes Chaumont (IDFM:71900): {Botzaris (IDFM:71906): {'duration': 60.0,
#                'routes': {'7B'}},
#               Bolivar (IDFM:71920): {'duration': 60.0, 'routes': {'7B'}}},
#              Bolivar (IDFM:71920): {Buttes Chaumont (IDFM:71900): {'duration': 60.0,
#                'routes': {'7B'}},
#               Jaurès (IDFM:71940): {'duration': 60.0, 'routes': {'7B'}}},
#              Place des Fêtes (IDFM:71885): {Botzaris (IDFM:71906): {'duration': 60.0,
#                'routes': {'7B'}},
#               Pré-Saint-Gervais (IDFM:71911): {'duration': 120.0,
#                'routes': {'7B'}},
#               Jourdain (IDFM:71868): {'duration': 60.0, 'routes': {'11'}},
#               Télégraphe (IDFM:71870): {'duration': 60.0, 'routes': {'11'}}},
#              Neuilly Porte Maillot (IDFM:71379): {Les Sablons (IDFM:425779): {'duration': 60.0,
#                'routes': {'1'}},
#               Argentine (IDFM:71348): {'duration': 60.0, 'routes': {'1'}}},
#              Les Sablons (IDFM:425779): {Neuilly Porte Maillot (IDFM:71379): {'duration': 60.0,
#                'routes': {'1'}},
#               Pont de Neuilly (IDFM:71442): {'duration': 60.0,
#                'routes': {'1'}}},
#              Pont de Neuilly (IDFM:71442): {Les Sablons (IDFM:425779): {'duration': 60.0,
#                'routes': {'1'}},
#               Esplanade de la Défense (IDFM:71485): {'duration': 60.0,
#                'routes': {'1'}}},
#              Esplanade de la Défense (IDFM:71485): {Pont de Neuilly (IDFM:71442): {'duration': 60.0,
#                'routes': {'1'}},
#               La Défense (IDFM:71517): {'duration': 60.0, 'routes': {'1'}}},
#              La Défense (IDFM:71517): {Esplanade de la Défense (IDFM:71485): {'duration': 60.0,
#                'routes': {'1'}}},
#              Porte de Versailles (IDFM:71045): {Corentin Celton (IDFM:70990): {'duration': 60.0,
#                'routes': {'12'}},
#               Convention (IDFM:71075): {'duration': 60.0, 'routes': {'12'}}},
#              Corentin Celton (IDFM:70990): {Porte de Versailles (IDFM:71045): {'duration': 60.0,
#                'routes': {'12'}},
#               Mairie d'Issy (IDFM:70671): {'duration': 60.0,
#                'routes': {'12'}}},
#              Mairie d'Issy (IDFM:70671): {Corentin Celton (IDFM:70990): {'duration': 60.0,
#                'routes': {'12'}}},
#              Convention (IDFM:71075): {Porte de Versailles (IDFM:71045): {'duration': 60.0,
#                'routes': {'12'}},
#               Vaugirard (IDFM:71091): {'duration': 60.0, 'routes': {'12'}}},
#              Vaugirard (IDFM:71091): {Convention (IDFM:71075): {'duration': 60.0,
#                'routes': {'12'}},
#               Volontaires (IDFM:71113): {'duration': 60.0, 'routes': {'12'}}},
#              Volontaires (IDFM:71113): {Vaugirard (IDFM:71091): {'duration': 60.0,
#                'routes': {'12'}},
#               Pasteur (IDFM:71125): {'duration': 60.0, 'routes': {'12'}}},
#              Falguière (IDFM:73641): {Pasteur (IDFM:71125): {'duration': 60.0,
#                'routes': {'12'}},
#               Gare Montparnasse (IDFM:71139): {'duration': 60.0,
#                'routes': {'12'}}},
#              Notre-Dame des Champs (IDFM:71138): {Gare Montparnasse (IDFM:71139): {'duration': 60.0,
#                'routes': {'12'}},
#               Rennes (IDFM:73640): {'duration': 60.0, 'routes': {'12'}}},
#              Rennes (IDFM:73640): {Notre-Dame des Champs (IDFM:71138): {'duration': 60.0,
#                'routes': {'12'}},
#               Sèvres - Babylone (IDFM:71203): {'duration': 60.0,
#                'routes': {'12'}}},
#              Rue du Bac (IDFM:71227): {Sèvres - Babylone (IDFM:71203): {'duration': 60.0,
#                'routes': {'12'}},
#               Solférino (IDFM:71270): {'duration': 60.0, 'routes': {'12'}}},
#              Solférino (IDFM:71270): {Rue du Bac (IDFM:71227): {'duration': 60.0,
#                'routes': {'12'}},
#               Assemblée Nationale (IDFM:73642): {'duration': 60.0,
#                'routes': {'12'}}},
#              Assemblée Nationale (IDFM:73642): {Solférino (IDFM:71270): {'duration': 60.0,
#                'routes': {'12'}},
#               Concorde (IDFM:71298): {'duration': 60.0, 'routes': {'12'}}},
#              Concorde (IDFM:71298): {Assemblée Nationale (IDFM:73642): {'duration': 60.0,
#                'routes': {'12'}},
#               Madeleine (IDFM:71324): {'duration': 60.0,
#                'routes': {'12', '8'}},
#               Invalides (IDFM:71274): {'duration': 60.0, 'routes': {'8'}},
#               Champs-Élysées - Clemenceau (IDFM:71305): {'duration': 60.0,
#                'routes': {'1'}},
#               Tuileries (IDFM:71284): {'duration': 60.0, 'routes': {'1'}}},
#              Madeleine (IDFM:71324): {Concorde (IDFM:71298): {'duration': 60.0,
#                'routes': {'12', '8'}},
#               Gare Saint-Lazare (IDFM:71370): {'duration': 60.0,
#                'routes': {'12', '14'}},
#               Opéra (IDFM:71337): {'duration': 60.0, 'routes': {'8'}},
#               Pyramides (IDFM:73788): {'duration': 60.0, 'routes': {'14'}}},
#              Trinité - d'Estienne d'Orves (IDFM:71355): {Gare Saint-Lazare (IDFM:71370): {'duration': 60.0,
#                'routes': {'12'}},
#               Notre-Dame-de-Lorette (IDFM:71350): {'duration': 60.0,
#                'routes': {'12'}}},
#              Notre-Dame-de-Lorette (IDFM:71350): {Trinité - d'Estienne d'Orves (IDFM:71355): {'duration': 60.0,
#                'routes': {'12'}},
#               Saint-Georges (IDFM:71366): {'duration': 60.0,
#                'routes': {'12'}}},
#              Saint-Georges (IDFM:71366): {Notre-Dame-de-Lorette (IDFM:71350): {'duration': 60.0,
#                'routes': {'12'}},
#               Pigalle (IDFM:71409): {'duration': 60.0, 'routes': {'12'}}},
#              Pigalle (IDFM:71409): {Saint-Georges (IDFM:71366): {'duration': 60.0,
#                'routes': {'12'}},
#               Abbesses (IDFM:71432): {'duration': 60.0, 'routes': {'12'}},
#               Anvers (IDFM:71419): {'duration': 60.0, 'routes': {'2'}},
#               Blanche (IDFM:71420): {'duration': 60.0, 'routes': {'2'}}},
#              Abbesses (IDFM:71432): {Pigalle (IDFM:71409): {'duration': 60.0,
#                'routes': {'12'}},
#               Lamarck - Caulaincourt (IDFM:71492): {'duration': 60.0,
#                'routes': {'12'}}},
#              Lamarck - Caulaincourt (IDFM:71492): {Abbesses (IDFM:71432): {'duration': 60.0,
#                'routes': {'12'}},
#               Jules Joffrin (IDFM:71521): {'duration': 60.0,
#                'routes': {'12'}}},
#              Jules Joffrin (IDFM:71521): {Lamarck - Caulaincourt (IDFM:71492): {'duration': 60.0,
#                'routes': {'12'}},
#               Marcadet - Poissonniers (IDFM:71511): {'duration': 60.0,
#                'routes': {'12'}}},
#              Marcadet - Poissonniers (IDFM:71511): {Jules Joffrin (IDFM:71521): {'duration': 60.0,
#                'routes': {'12'}},
#               Marx Dormoy (IDFM:71510): {'duration': 60.0, 'routes': {'12'}},
#               Simplon (IDFM:71556): {'duration': 60.0, 'routes': {'4'}},
#               Château Rouge (IDFM:71469): {'duration': 60.0, 'routes': {'4'}}},
#              Marx Dormoy (IDFM:71510): {Marcadet - Poissonniers (IDFM:71511): {'duration': 60.0,
#                'routes': {'12'}},
#               Porte de la Chapelle (IDFM:72064): {'duration': 60.0,
#                'routes': {'12'}}},
#              Porte de la Chapelle (IDFM:72064): {Marx Dormoy (IDFM:71510): {'duration': 60.0,
#                'routes': {'12'}},
#               Front Populaire (IDFM:74041): {'duration': 120.0,
#                'routes': {'12'}}},
#              Front Populaire (IDFM:74041): {Porte de la Chapelle (IDFM:72064): {'duration': 120.0,
#                'routes': {'12'}},
#               Aimé Césaire (IDFM:72491): {'duration': 120.0,
#                'routes': {'12'}}},
#              Aimé Césaire (IDFM:72491): {Front Populaire (IDFM:74041): {'duration': 120.0,
#                'routes': {'12'}},
#               Mairie d'Aubervilliers (IDFM:72524): {'duration': 60.0,
#                'routes': {'12'}}},
#              Mairie d'Aubervilliers (IDFM:72524): {Aimé Césaire (IDFM:72491): {'duration': 60.0,
#                'routes': {'12'}}},
#              Balard (IDFM:71073): {Lourmel (IDFM:71086): {'duration': 60.0,
#                'routes': {'8'}}},
#              Lourmel (IDFM:71086): {Balard (IDFM:71073): {'duration': 60.0,
#                'routes': {'8'}},
#               Boucicaut (IDFM:412992): {'duration': 60.0, 'routes': {'8'}}},
#              Boucicaut (IDFM:412992): {Lourmel (IDFM:71086): {'duration': 60.0,
#                'routes': {'8'}},
#               Félix Faure (IDFM:71137): {'duration': 60.0, 'routes': {'8'}}},
#              Félix Faure (IDFM:71137): {Boucicaut (IDFM:412992): {'duration': 60.0,
#                'routes': {'8'}},
#               Commerce (IDFM:71132): {'duration': 60.0, 'routes': {'8'}}},
#              Commerce (IDFM:71132): {Félix Faure (IDFM:71137): {'duration': 60.0,
#                'routes': {'8'}},
#               La Motte-Picquet - Grenelle (IDFM:71199): {'duration': 60.0,
#                'routes': {'8'}}},
#              École Militaire (IDFM:71224): {La Motte-Picquet - Grenelle (IDFM:71199): {'duration': 60.0,
#                'routes': {'8'}},
#               La Tour-Maubourg (IDFM:71242): {'duration': 60.0,
#                'routes': {'8'}}},
#              La Tour-Maubourg (IDFM:71242): {École Militaire (IDFM:71224): {'duration': 60.0,
#                'routes': {'8'}},
#               Invalides (IDFM:71274): {'duration': 60.0, 'routes': {'8'}}},
#              Invalides (IDFM:71274): {La Tour-Maubourg (IDFM:71242): {'duration': 60.0,
#                'routes': {'8'}},
#               Concorde (IDFM:71298): {'duration': 60.0, 'routes': {'8'}},
#               Champs-Élysées - Clemenceau (IDFM:71305): {'duration': 60.0,
#                'routes': {'13'}},
#               Varenne (IDFM:71232): {'duration': 60.0, 'routes': {'13'}}},
#              Richelieu - Drouot (IDFM:71330): {Opéra (IDFM:71337): {'duration': 60.0,
#                'routes': {'8'}},
#               Grands Boulevards (IDFM:71326): {'duration': 60.0,
#                'routes': {'8', '9'}},
#               Chaussée d'Antin - La Fayette (IDFM:73689): {'duration': 60.0,
#                'routes': {'9'}}},
#              Grands Boulevards (IDFM:71326): {Richelieu - Drouot (IDFM:71330): {'duration': 60.0,
#                'routes': {'8', '9'}},
#               Bonne Nouvelle (IDFM:71320): {'duration': 60.0,
#                'routes': {'8', '9'}}},
#              Bonne Nouvelle (IDFM:71320): {Grands Boulevards (IDFM:71326): {'duration': 60.0,
#                'routes': {'8', '9'}},
#               Strasbourg - Saint-Denis (IDFM:73633): {'duration': 60.0,
#                'routes': {'8', '9'}}},
#              Strasbourg - Saint-Denis (IDFM:73633): {Bonne Nouvelle (IDFM:71320): {'duration': 60.0,
#                'routes': {'8', '9'}},
#               République (IDFM:71311): {'duration': 60.0,
#                'routes': {'8', '9'}},
#               Château d'Eau (IDFM:71333): {'duration': 60.0, 'routes': {'4'}},
#               Réaumur - Sébastopol (IDFM:73636): {'duration': 60.0,
#                'routes': {'4'}}},
#              Filles du Calvaire (IDFM:71277): {République (IDFM:71311): {'duration': 60.0,
#                'routes': {'8'}},
#               Saint-Sébastien - Froissart (IDFM:71777): {'duration': 60.0,
#                'routes': {'8'}}},
#              Saint-Sébastien - Froissart (IDFM:71777): {Filles du Calvaire (IDFM:71277): {'duration': 60.0,
#                'routes': {'8'}},
#               Chemin Vert (IDFM:73622): {'duration': 60.0, 'routes': {'8'}}},
#              Chemin Vert (IDFM:73622): {Saint-Sébastien - Froissart (IDFM:71777): {'duration': 60.0,
#                'routes': {'8'}},
#               Bastille (IDFM:463564): {'duration': 60.0, 'routes': {'8'}}},
#              Ledru-Rollin (IDFM:71693): {Bastille (IDFM:463564): {'duration': 60.0,
#                'routes': {'8'}},
#               Faidherbe - Chaligny (IDFM:74001): {'duration': 60.0,
#                'routes': {'8'}}},
#              Faidherbe - Chaligny (IDFM:74001): {Ledru-Rollin (IDFM:71693): {'duration': 60.0,
#                'routes': {'8'}},
#               Reuilly - Diderot (IDFM:71654): {'duration': 60.0,
#                'routes': {'8'}}},
#              Reuilly - Diderot (IDFM:71654): {Faidherbe - Chaligny (IDFM:74001): {'duration': 60.0,
#                'routes': {'8'}},
#               Montgallet (IDFM:71631): {'duration': 60.0, 'routes': {'8'}},
#               Gare de Lyon (IDFM:73626): {'duration': 60.0, 'routes': {'1'}},
#               Nation (IDFM:71673): {'duration': 120.0, 'routes': {'1'}}},
#              Montgallet (IDFM:71631): {Reuilly - Diderot (IDFM:71654): {'duration': 60.0,
#                'routes': {'8'}},
#               Daumesnil (IDFM:71614): {'duration': 60.0, 'routes': {'8'}}},
#              Daumesnil (IDFM:71614): {Montgallet (IDFM:71631): {'duration': 60.0,
#                'routes': {'8'}},
#               Michel Bizot (IDFM:71595): {'duration': 60.0, 'routes': {'8'}},
#               Bel-Air (IDFM:73650): {'duration': 60.0, 'routes': {'6'}},
#               Dugommier (IDFM:71606): {'duration': 60.0, 'routes': {'6'}}},
#              Michel Bizot (IDFM:71595): {Daumesnil (IDFM:71614): {'duration': 60.0,
#                'routes': {'8'}},
#               Porte Dorée (IDFM:71591): {'duration': 60.0, 'routes': {'8'}}},
#              Porte Dorée (IDFM:71591): {Michel Bizot (IDFM:71595): {'duration': 60.0,
#                'routes': {'8'}},
# ...
#                'routes': {'9'}},
#               Picpus (IDFM:71639): {'duration': 60.0, 'routes': {'6'}}},
#              Porte de Vincennes (IDFM:71663): {Nation (IDFM:71673): {'duration': 60.0,
#                'routes': {'1'}},
#               Saint-Mandé (IDFM:71647): {'duration': 60.0, 'routes': {'1'}}},
#              Saint-Mandé (IDFM:71647): {Porte de Vincennes (IDFM:71663): {'duration': 60.0,
#                'routes': {'1'}},
#               Bérault (IDFM:71650): {'duration': 60.0, 'routes': {'1'}}},
#              Bérault (IDFM:71650): {Saint-Mandé (IDFM:71647): {'duration': 60.0,
#                'routes': {'1'}},
#               Château de Vincennes (IDFM:71634): {'duration': 60.0,
#                'routes': {'1'}}},
#              Château de Vincennes (IDFM:71634): {Bérault (IDFM:71650): {'duration': 60.0,
#                'routes': {'1'}}},
#              Mairie d'Ivry (IDFM:70488): {Pierre et Marie Curie (IDFM:70537): {'duration': 60.0,
#                'routes': {'7'}}},
#              Pierre et Marie Curie (IDFM:70537): {Mairie d'Ivry (IDFM:70488): {'duration': 60.0,
#                'routes': {'7'}},
#               Porte d'Ivry (IDFM:70636): {'duration': 120.0, 'routes': {'7'}}},
#              Porte d'Ivry (IDFM:70636): {Pierre et Marie Curie (IDFM:70537): {'duration': 120.0,
#                'routes': {'7'}},
#               Porte de Choisy (IDFM:70604): {'duration': 60.0,
#                'routes': {'7'}}},
#              Porte de Choisy (IDFM:70604): {Porte d'Ivry (IDFM:70636): {'duration': 60.0,
#                'routes': {'7'}},
#               Porte d'Italie (IDFM:70596): {'duration': 120.0,
#                'routes': {'7'}}},
#              Porte d'Italie (IDFM:70596): {Porte de Choisy (IDFM:70604): {'duration': 120.0,
#                'routes': {'7'}},
#               Maison Blanche (IDFM:70645): {'duration': 60.0,
#                'routes': {'7'}}},
#              Avron (IDFM:71697): {Nation (IDFM:71673): {'duration': 60.0,
#                'routes': {'2'}},
#               Alexandre Dumas (IDFM:71728): {'duration': 60.0,
#                'routes': {'2'}}},
#              Alexandre Dumas (IDFM:71728): {Avron (IDFM:71697): {'duration': 60.0,
#                'routes': {'2'}},
#               Philippe Auguste (IDFM:71751): {'duration': 60.0,
#                'routes': {'2'}}},
#              Philippe Auguste (IDFM:71751): {Alexandre Dumas (IDFM:71728): {'duration': 60.0,
#                'routes': {'2'}},
#               Père Lachaise (IDFM:71787): {'duration': 60.0, 'routes': {'2'}}},
#              Ménilmontant (IDFM:71815): {Père Lachaise (IDFM:71787): {'duration': 60.0,
#                'routes': {'2'}},
#               Couronnes (IDFM:71834): {'duration': 60.0, 'routes': {'2'}}},
#              Couronnes (IDFM:71834): {Ménilmontant (IDFM:71815): {'duration': 60.0,
#                'routes': {'2'}},
#               Belleville (IDFM:71853): {'duration': 60.0, 'routes': {'2'}}},
#              Belleville (IDFM:71853): {Couronnes (IDFM:71834): {'duration': 60.0,
#                'routes': {'2'}},
#               Colonel Fabien (IDFM:71893): {'duration': 60.0, 'routes': {'2'}},
#               Goncourt (IDFM:71840): {'duration': 60.0, 'routes': {'11'}},
#               Pyrénées (IDFM:71864): {'duration': 60.0, 'routes': {'11'}}},
#              Colonel Fabien (IDFM:71893): {Belleville (IDFM:71853): {'duration': 60.0,
#                'routes': {'2'}},
#               Jaurès (IDFM:71940): {'duration': 60.0, 'routes': {'2'}}},
#              La Chapelle (IDFM:71434): {Stalingrad (IDFM:71961): {'duration': 60.0,
#                'routes': {'2'}},
#               Barbès - Rochechouart (IDFM:71426): {'duration': 60.0,
#                'routes': {'2'}}},
#              Barbès - Rochechouart (IDFM:71426): {La Chapelle (IDFM:71434): {'duration': 60.0,
#                'routes': {'2'}},
#               Anvers (IDFM:71419): {'duration': 60.0, 'routes': {'2'}},
#               Château Rouge (IDFM:71469): {'duration': 60.0, 'routes': {'4'}},
#               Gare du Nord (IDFM:71410): {'duration': 120.0, 'routes': {'4'}}},
#              Anvers (IDFM:71419): {Barbès - Rochechouart (IDFM:71426): {'duration': 60.0,
#                'routes': {'2'}},
#               Pigalle (IDFM:71409): {'duration': 60.0, 'routes': {'2'}}},
#              Blanche (IDFM:71420): {Pigalle (IDFM:71409): {'duration': 60.0,
#                'routes': {'2'}},
#               Place de Clichy (IDFM:71435): {'duration': 60.0,
#                'routes': {'2'}}},
#              Rome (IDFM:71408): {Place de Clichy (IDFM:71435): {'duration': 60.0,
#                'routes': {'2'}},
#               Villiers (IDFM:71403): {'duration': 60.0, 'routes': {'2'}}},
#              Monceau (IDFM:73671): {Villiers (IDFM:71403): {'duration': 60.0,
#                'routes': {'2'}},
#               Courcelles (IDFM:71376): {'duration': 60.0, 'routes': {'2'}}},
#              Courcelles (IDFM:71376): {Monceau (IDFM:73671): {'duration': 60.0,
#                'routes': {'2'}},
#               Ternes (IDFM:71367): {'duration': 60.0, 'routes': {'2'}}},
#              Ternes (IDFM:71367): {Courcelles (IDFM:71376): {'duration': 60.0,
#                'routes': {'2'}},
#               Charles de Gaulle - Etoile (IDFM:71347): {'duration': 60.0,
#                'routes': {'2'}}},
#              Victor Hugo (IDFM:71315): {Charles de Gaulle - Etoile (IDFM:71347): {'duration': 60.0,
#                'routes': {'2'}},
#               Porte Dauphine (IDFM:474152): {'duration': 60.0,
#                'routes': {'2'}}},
#              Porte Dauphine (IDFM:474152): {Victor Hugo (IDFM:71315): {'duration': 60.0,
#                'routes': {'2'}}},
#              Bercy (IDFM:71607): {Gare de Lyon (IDFM:73626): {'duration': 60.0,
#                'routes': {'14'}},
#               Cour Saint-Emilion (IDFM:71576): {'duration': 60.0,
#                'routes': {'14'}},
#               Dugommier (IDFM:71606): {'duration': 60.0, 'routes': {'6'}},
#               Quai de la Gare (IDFM:71597): {'duration': 60.0,
#                'routes': {'6'}}},
#              Cour Saint-Emilion (IDFM:71576): {Bercy (IDFM:71607): {'duration': 60.0,
#                'routes': {'14'}},
#               Bibliothèque François Mitterrand (IDFM:71572): {'duration': 60.0,
#                'routes': {'14'}}},
#              Bibliothèque François Mitterrand (IDFM:71572): {Cour Saint-Emilion (IDFM:71576): {'duration': 60.0,
#                'routes': {'14'}},
#               Olympiades (IDFM:71557): {'duration': 60.0, 'routes': {'14'}}},
#              Olympiades (IDFM:71557): {Bibliothèque François Mitterrand (IDFM:71572): {'duration': 60.0,
#                'routes': {'14'}}},
#              Pont Cardinet (IDFM:71475): {Gare Saint-Lazare (IDFM:71370): {'duration': 120.0,
#                'routes': {'14'}},
#               Porte de Clichy (IDFM:71545): {'duration': 60.0,
#                'routes': {'14'}}},
#              Saint-Ouen (IDFM:72126): {Porte de Clichy (IDFM:71545): {'duration': 120.0,
#                'routes': {'14'}},
#               Mairie de Saint-Ouen (IDFM:72168): {'duration': 60.0,
#                'routes': {'14'}}},
#              Rambuteau (IDFM:71273): {Hôtel de Ville (IDFM:415852): {'duration': 60.0,
#                'routes': {'11'}},
#               Arts et Métiers (IDFM:71293): {'duration': 60.0,
#                'routes': {'11'}}},
#              Goncourt (IDFM:71840): {République (IDFM:71311): {'duration': 60.0,
#                'routes': {'11'}},
#               Belleville (IDFM:71853): {'duration': 60.0, 'routes': {'11'}}},
#              Pyrénées (IDFM:71864): {Belleville (IDFM:71853): {'duration': 60.0,
#                'routes': {'11'}},
#               Jourdain (IDFM:71868): {'duration': 60.0, 'routes': {'11'}}},
#              Jourdain (IDFM:71868): {Pyrénées (IDFM:71864): {'duration': 60.0,
#                'routes': {'11'}},
#               Place des Fêtes (IDFM:71885): {'duration': 60.0,
#                'routes': {'11'}}},
#              Télégraphe (IDFM:71870): {Place des Fêtes (IDFM:71885): {'duration': 60.0,
#                'routes': {'11'}},
#               Porte des Lilas (IDFM:71889): {'duration': 60.0,
#                'routes': {'11'}}},
#              Mairie des Lilas (IDFM:71909): {Porte des Lilas (IDFM:71889): {'duration': 60.0,
#                'routes': {'11'}}},
#              Maraîchers (IDFM:71703): {Porte de Montreuil (IDFM:71710): {'duration': 60.0,
#                'routes': {'9'}},
#               Buzenval (IDFM:479928): {'duration': 60.0, 'routes': {'9'}}},
#              Buzenval (IDFM:479928): {Maraîchers (IDFM:71703): {'duration': 60.0,
#                'routes': {'9'}},
#               Nation (IDFM:71673): {'duration': 60.0, 'routes': {'9'}}},
#              Rue des Boulets (IDFM:71694): {Nation (IDFM:71673): {'duration': 60.0,
#                'routes': {'9'}},
#               Charonne (IDFM:73647): {'duration': 60.0, 'routes': {'9'}}},
#              Charonne (IDFM:73647): {Rue des Boulets (IDFM:71694): {'duration': 60.0,
#                'routes': {'9'}},
#               Voltaire (IDFM:71750): {'duration': 60.0, 'routes': {'9'}}},
#              Voltaire (IDFM:71750): {Charonne (IDFM:73647): {'duration': 60.0,
#                'routes': {'9'}},
#               Saint-Ambroise (IDFM:71781): {'duration': 60.0,
#                'routes': {'9'}}},
#              Saint-Ambroise (IDFM:71781): {Voltaire (IDFM:71750): {'duration': 60.0,
#                'routes': {'9'}},
#               Oberkampf (IDFM:71803): {'duration': 60.0, 'routes': {'9'}}},
#              Saint-Augustin (IDFM:73690): {Havre - Caumartin (IDFM:482368): {'duration': 60.0,
#                'routes': {'9'}},
#               Miromesnil (IDFM:71346): {'duration': 60.0, 'routes': {'9'}}},
#              Saint-Philippe du Roule (IDFM:71334): {Miromesnil (IDFM:71346): {'duration': 60.0,
#                'routes': {'9'}},
#               Franklin D. Roosevelt (IDFM:71318): {'duration': 60.0,
#                'routes': {'9'}}},
#              Alma - Marceau (IDFM:71290): {Franklin D. Roosevelt (IDFM:71318): {'duration': 60.0,
#                'routes': {'9'}},
#               Iéna (IDFM:71294): {'duration': 60.0, 'routes': {'9'}}},
#              Iéna (IDFM:71294): {Alma - Marceau (IDFM:71290): {'duration': 60.0,
#                'routes': {'9'}},
#               Trocadéro (IDFM:71285): {'duration': 60.0, 'routes': {'9'}}},
#              Rue de la Pompe (IDFM:71292): {Trocadéro (IDFM:71285): {'duration': 60.0,
#                'routes': {'9'}},
#               La Muette (IDFM:474150): {'duration': 60.0, 'routes': {'9'}}},
#              La Muette (IDFM:474150): {Rue de la Pompe (IDFM:71292): {'duration': 60.0,
#                'routes': {'9'}},
#               Ranelagh (IDFM:71243): {'duration': 60.0, 'routes': {'9'}}},
#              Ranelagh (IDFM:71243): {La Muette (IDFM:474150): {'duration': 60.0,
#                'routes': {'9'}},
#               Jasmin (IDFM:73657): {'duration': 60.0, 'routes': {'9'}}},
#              Jasmin (IDFM:73657): {Ranelagh (IDFM:71243): {'duration': 60.0,
#                'routes': {'9'}},
#               Michel-Ange - Auteuil (IDFM:71206): {'duration': 60.0,
#                'routes': {'9'}}},
#              Exelmans (IDFM:71124): {Michel-Ange - Molitor (IDFM:73658): {'duration': 60.0,
#                'routes': {'9'}},
#               Porte de Saint-Cloud (IDFM:71084): {'duration': 60.0,
#                'routes': {'9'}}},
#              Porte de Clignancourt (IDFM:478883): {Simplon (IDFM:71556): {'duration': 60.0,
#                'routes': {'4'}}},
#              Simplon (IDFM:71556): {Porte de Clignancourt (IDFM:478883): {'duration': 60.0,
#                'routes': {'4'}},
#               Marcadet - Poissonniers (IDFM:71511): {'duration': 60.0,
#                'routes': {'4'}}},
#              Château Rouge (IDFM:71469): {Marcadet - Poissonniers (IDFM:71511): {'duration': 60.0,
#                'routes': {'4'}},
#               Barbès - Rochechouart (IDFM:71426): {'duration': 60.0,
#                'routes': {'4'}}},
#              Château d'Eau (IDFM:71333): {Gare de l'Est (IDFM:71359): {'duration': 60.0,
#                'routes': {'4'}},
#               Strasbourg - Saint-Denis (IDFM:73633): {'duration': 60.0,
#                'routes': {'4'}}},
#              Etienne Marcel (IDFM:479068): {Réaumur - Sébastopol (IDFM:73636): {'duration': 60.0,
#                'routes': {'4'}},
#               Les Halles (IDFM:73794): {'duration': 60.0, 'routes': {'4'}}},
#              Les Halles (IDFM:73794): {Etienne Marcel (IDFM:479068): {'duration': 60.0,
#                'routes': {'4'}},
#               Châtelet (IDFM:71264): {'duration': 60.0, 'routes': {'4'}}},
#              Cité (IDFM:71223): {Châtelet (IDFM:71264): {'duration': 60.0,
#                'routes': {'4'}},
#               Saint-Michel Notre-Dame (IDFM:73620): {'duration': 60.0,
#                'routes': {'4'}}},
#              Saint-Michel Notre-Dame (IDFM:73620): {Cité (IDFM:71223): {'duration': 60.0,
#                'routes': {'4'}},
#               Odéon (IDFM:73618): {'duration': 60.0, 'routes': {'4'}}},
#              Saint-Germain-des-Prés (IDFM:71216): {Odéon (IDFM:73618): {'duration': 60.0,
#                'routes': {'4'}},
#               Saint-Sulpice (IDFM:71202): {'duration': 60.0, 'routes': {'4'}}},
#              Saint-Sulpice (IDFM:71202): {Saint-Germain-des-Prés (IDFM:71216): {'duration': 60.0,
#                'routes': {'4'}},
#               Saint-Placide (IDFM:71184): {'duration': 60.0, 'routes': {'4'}}},
#              Saint-Placide (IDFM:71184): {Saint-Sulpice (IDFM:71202): {'duration': 60.0,
#                'routes': {'4'}},
#               Gare Montparnasse (IDFM:71139): {'duration': 60.0,
#                'routes': {'4'}}},
#              Vavin (IDFM:71117): {Gare Montparnasse (IDFM:71139): {'duration': 60.0,
#                'routes': {'4'}},
#               Raspail (IDFM:71088): {'duration': 60.0, 'routes': {'4'}}},
#              Mouton-Duvernet (IDFM:73653): {Denfert-Rochereau (IDFM:71056): {'duration': 60.0,
#                'routes': {'4'}},
#               Alésia (IDFM:71030): {'duration': 60.0, 'routes': {'4'}}},
#              Alésia (IDFM:71030): {Mouton-Duvernet (IDFM:73653): {'duration': 60.0,
#                'routes': {'4'}},
#               Porte d'Orléans (IDFM:70657): {'duration': 60.0,
#                'routes': {'4'}}},
#              Porte d'Orléans (IDFM:70657): {Alésia (IDFM:71030): {'duration': 60.0,
#                'routes': {'4'}},
#               Mairie de Montrouge (IDFM:70586): {'duration': 60.0,
#                'routes': {'4'}}},
#              Mairie de Montrouge (IDFM:70586): {Porte d'Orléans (IDFM:70657): {'duration': 60.0,
#                'routes': {'4'}},
#               Barbara (IDFM:70441): {'duration': 120.0, 'routes': {'4'}}},
#              Barbara (IDFM:70441): {Mairie de Montrouge (IDFM:70586): {'duration': 120.0,
#                'routes': {'4'}},
#               Bagneux - Lucie Aubrac (IDFM:483315): {'duration': 60.0,
#                'routes': {'4'}}},
#              Bagneux - Lucie Aubrac (IDFM:483315): {Barbara (IDFM:70441): {'duration': 60.0,
#                'routes': {'4'}}},
#              Picpus (IDFM:71639): {Nation (IDFM:71673): {'duration': 60.0,
#                'routes': {'6'}},
#               Bel-Air (IDFM:73650): {'duration': 60.0, 'routes': {'6'}}},
#              Bel-Air (IDFM:73650): {Picpus (IDFM:71639): {'duration': 60.0,
#                'routes': {'6'}},
#               Daumesnil (IDFM:71614): {'duration': 60.0, 'routes': {'6'}}},
#              Dugommier (IDFM:71606): {Daumesnil (IDFM:71614): {'duration': 60.0,
#                'routes': {'6'}},
#               Bercy (IDFM:71607): {'duration': 60.0, 'routes': {'6'}}},
#              Quai de la Gare (IDFM:71597): {Bercy (IDFM:71607): {'duration': 60.0,
#                'routes': {'6'}},
#               Chevaleret (IDFM:73651): {'duration': 60.0, 'routes': {'6'}}},
#              Chevaleret (IDFM:73651): {Quai de la Gare (IDFM:71597): {'duration': 60.0,
#                'routes': {'6'}},
#               Nationale (IDFM:71043): {'duration': 60.0, 'routes': {'6'}}},
#              Nationale (IDFM:71043): {Chevaleret (IDFM:73651): {'duration': 60.0,
#                'routes': {'6'}},
#               Place d'Italie (IDFM:71033): {'duration': 60.0,
#                'routes': {'6'}}}})

# %% [markdown]
# ### Tests du graphe

# %%
def is_connected(graph):
    if not graph:
        return True  # An empty graph is trivially connected

    visited = set()
    start = next(iter(graph))  # Start from any node
    
    def dfs(node):
        visited.add(node)
        for neighbor in graph[node]:
            if neighbor not in visited:
                dfs(neighbor)

    dfs(start)
    return (len(visited) == len(graph), visited)

# %%
def test_connexite(graph):
    est_connnexe, visited = is_connected(graph)
    if not est_connnexe:
        for g in graph:
            if g not in visited:
                print(g)
    else:
        print('Le graphe est connexe.')

test_connexite(graph)
# Out:
# Le graphe est connexe.

# %%
len(graph)
# Out:
# 308

# %% [markdown]
# ### Test classe MetroGraph

# %%
from MetroGraph import MetroGraph

# %%
g = MetroGraph(stop_dict, edges)

# %%
odeon_stops = g.get_stops_by_name("Odéon")
for stop in odeon_stops:
    print(stop, "→", g.voisins(stop))
# Out:
# Odéon (IDFM:73618) → {Mabillon (IDFM:73639): 60.0, Cluny - La Sorbonne (IDFM:73619): 60.0, Saint-Michel Notre-Dame (IDFM:73620): 60.0, Saint-Germain-des-Prés (IDFM:71216): 60.0}

# %%
est_connexe, visited = g.is_connected()
print("Graphe connexe :", est_connexe)
# Out:
# Graphe connexe : True

# %% [markdown]
# ## Sauvegarde du graphe

# %%
import pickle

with open("metro_graph.pkl", "wb") as f:
    pickle.dump(g, f)
